# %% [markdown]
# ### Librerias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import holidays
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

from functools import partial# import ace_tools as tools

# %% [markdown]
# ### Directorios

# %%
DATOS_DIR = '../data/'
SALIDAS_DIR = '../salidas/'

# %% [markdown]
# Lectura de datos

# %%
FILE_NAME_INPUT='sell_in_03-featureaddv1.parquet"'

df = pd.read_parquet(SALIDAS_DIR + FILE_NAME_INPUT)

# %%
df.info()
df.head(40)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16422912 entries, 0 to 16215443
# Data columns (total 39 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   customer_id            int32
#  1   product_id             int32
#  2   plan_precios_cuidados  int8
#  3   cust_request_qty       float32
#  4   cust_request_tn        float32
#  5   tn                     float32
#  6   cat1                   category
#  7   cat2                   category
#  8   cat3                   category
#  9   brand                  category
#  10  sku_size               int32
#  11  periodo_indice         int16
#  12  year                   int16
#  13  month                  int8
#  14  quarter                int8
#  15  month_idx              int32
#  16  is_fy_start            int8
#  17  is_fy_end              int8
#  18  season                 category
#  19  mes_anormal_1          int8
#  20  mes_anormal_2          int8
#  21  clase                  float32
# ...

# %% [markdown]
# ### hago unos casteos para optimizacion

# %%
# cast rápidos
df["sku_size"] = df["sku_size"].astype("int32")
df["periodo_indice"]  = df["periodo_indice"].astype("int16")
df["cust_request_qty"] = df["cust_request_qty"].astype("float32")

for col in ["cat1","cat2","cat3","brand"]:
    df[col] = df[col].astype("category")
